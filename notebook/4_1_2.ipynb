# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



AAPL = pd.read_csv(r'../data/AAPL.csv', index_col = 0)
IBM = pd.read_csv(r'../data/IBM.csv', index_col = 0)
JPM = pd.read_csv(r'../data/JPM.csv', index_col = 0)
DJI = pd.read_csv(r'../data/DJI.csv', index_col = 0)

order = ["AAPL", "IBM", "JPM", "DJI"]

# %%
# # import data and obtain the 1-day returns
# AAPL = pd.read_csv(r'AAPL.csv', index_col = 0)
# AAPL['Return'] = AAPL['Adj Close'].pct_change()
# IBM = pd.read_csv(r'IBM.csv', index_col = 0)
# IBM['Return'] = IBM['Adj Close'].pct_change()
# JPM = pd.read_csv(r'JPM.csv', index_col = 0)
# JPM['Return'] = JPM['Adj Close'].pct_change()
# DJI = pd.read_csv(r'DJI.csv', index_col = 0)
# DJI['Return'] = DJI['Adj Close'].pct_change()

# %% [markdown]
# # Open

# %%
# mean = []

# mean.append(np.mean(AAPL['Open']))
# mean.append(np.mean(IBM['Open']))
# mean.append(np.mean(JPM['Open']))
# mean.append(np.mean(DJI['Open']))


# median = []

# median.append(np.median(AAPL['Open']))
# median.append(np.median(IBM['Open']))
# median.append(np.median(JPM['Open']))
# median.append(np.median(DJI['Open']))
# # print(mean)

# plt.bar(order,mean)
# # plt.hold(True)
# # plt.bar(order,median)
# plt.bar

# %% [markdown]
# # High

# %%
# mean = []

# mean.append(np.mean(AAPL['Open']))
# mean.append(np.mean(IBM['Open']))
# mean.append(np.mean(JPM['Open']))
# mean.append(np.mean(DJI['Open']))
# # print(mean)

# plt.bar(order,mean)

# %% [markdown]
# # Low

# %% [markdown]
# # Close

# %% [markdown]
# # Adj Close

# %% [markdown]
# # Volume

# %% [markdown]
# # 1 day return

# %%
AAPL['1DReturn'] = AAPL['Adj Close'].pct_change()
IBM['1DReturn'] = IBM['Adj Close'].pct_change()
JPM['1DReturn'] = JPM['Adj Close'].pct_change()
DJI['1DReturn'] = DJI['Adj Close'].pct_change()

# %% [markdown]
# # 4.1.2

# %%
plt.figure()


# AAPL['Adj Close'].hist(bins=100)
# plt.figure()
# AAPL['Adj Close'].plot.kde()
sns.distplot(AAPL['Adj Close'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

# plt.legend("pdf", "histogram")
plt.title("Histogram and PDF of AAPL[\"Adj CLose\"]")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_a.png",dpi=1200)

# %%
plt.figure()

sns.distplot(IBM['Adj Close'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of IBM[\"Adj CLose\"]")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_b.png",dpi=1200)

# %%
plt.figure()

sns.distplot(JPM['Adj Close'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of AAPL[\"Adj CLose\"]")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_c.png",dpi=1200)

# %%
plt.figure()

sns.distplot(DJI['Adj Close'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of AAPL[\"Adj CLose\"]")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_d.png",dpi=1200)

# %%
plt.figure()

sns.distplot(AAPL['1DReturn'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of 1-day returns of AAPL")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_e.png",dpi=1200)
# Out:
# C:\Users\thtan\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\thtan\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\Users\thtan\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\thtan\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
plt.figure()

sns.distplot(IBM['1DReturn'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of 1-day returns of AAPL")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_f.png",dpi=1200)

# %%
plt.figure()

sns.distplot(JPM['1DReturn'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of 1-day returns of AAPL")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_g.png",dpi=1200)

# %%
plt.figure()

sns.distplot(DJI['1DReturn'], hist=True, kde=True, 
             bins=30, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title("Histogram and PDF of 1-day returns of AAPL")
plt.ylabel("Density")
plt.savefig("../result/4_1_2_h.png",dpi=1200)
